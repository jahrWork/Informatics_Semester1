# %% [markdown]
# ## Notebook
# This is an example of math functions:
# $$
#    f(x) = x ^2
# $$

# %%
def f(x): 
    return x**3  

print( " f(2) = ", f(2) )
# Out:
#  f(2) =  8

# %%
import matplotlib.pyplot as plt 
import numpy as np 

x = np.linspace(0, 2, 100)
plt.plot(x, f(x) )
plt.show()
